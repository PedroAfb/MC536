# %% [markdown]
# ### Setup

# %% [markdown]
# Configure o seu ambiente instalando os pacote necessários:
#
# pip install psycopg2-binary nbformat pandas
#
# ou garanta que os pacotes acima estão instalados

# %% [markdown]
# Atualize o arquivo DATABASE_CONFIG.py com os dados do seu banco de dados

# %% [markdown]
# ### Insert Região Administrativa

# %%
# %run insert_regiao_administrativa.ipynb
# Out:
# Região Administrativa inserida com sucesso.
# Regiões Administrativas inseridas com sucesso.

# %% [markdown]
# ### Insert Estado

# %%
# %run insert_estado.ipynb
# Out:
# {'Amazônia Legal': 7, 'Centro-Oeste': 8, 'Nordeste': 9, 'Norte': 10, 'Sudeste': 11, 'Sul': 12}
# Estados inseridos com sucesso.
# {'Acre': 1, 'Amapá': 2, 'Amazonas': 3, 'Maranhão': 4, 'Mato Grosso': 5, 'Pará': 6, 'Rondônia': 7, 'Roraima': 8, 'Tocantins': 9}

# %% [markdown]
# ### Insert Cidade

# %%
# %run insert_cidade.ipynb

# %% [markdown]
# ### Insert Foco Queimadas

# %%
# %run insert_queimadas.ipynb
# Out:
# {'ACRE': 1, 'AMAPÁ': 2, 'AMAZONAS': 3, 'MARANHÃO': 4, 'MATO GROSSO': 5, 'PARÁ': 6, 'RONDÔNIA': 7, 'RORAIMA': 8, 'TOCANTINS': 9}
# Index(['mes_ano', 'tipo_area', 'quantidade', 'id_estado'], dtype='object')

# %% [markdown]
# ### Insert Area Indígena

# %%
# %run insert_indigena.ipynb

# %% [markdown]
# ### Insert Unidade Conservacao

# %%
# %run insert_unidade_conservacao.ipynb
# Out:
# [('Reserva Particular Do Patrimônio Natural Fazenda Estância Dorochê', 'Reserva Particular do Patrimônio Natural', 'Federal', 'Uso Sustentável', 0.0, 5.0), ('Reserva Particular Do Patrimônio Natural Jubran', 'Reserva Particular do Patrimônio Natural', 'Federal', 'Uso Sustentável', 0.0, 5.0), ('Reserva Particular Do Patrimônio Natural Estância Ecológica Sesc - Pantanal', 'Reserva Particular do Patrimônio Natural', 'Federal', 'Uso Sustentável', 0.0, 5.0), ('Reserva Particular Do Patrimônio Natural Estância Ecológica Sesc - Pantanal', 'Reserva Particular do Patrimônio Natural', 'Federal', 'Uso Sustentável', 0.0, 5.0), ('Estação Ecológica De Taiamã', 'Estação Ecológica', 'Federal', 'Proteção Integral', 0.0, 5.0), ('Parque Estadual Do Guirá', 'Parque', 'Estadual', 'Proteção Integral', 0.0, 5.0), ('Parque Estadual Encontro Das Águas', 'Parque', 'Estadual', 'Proteção Integral', 0.0, 5.0), ('Parque Estadual Marinho Do Parcel De Manuel Luís', 'Parque', 'Estadual', 'Proteção Integral', 0.0, 4.0), ('Parque Estadual Marinho Banco Do Tarol', 'Parque', 'Estadual', 'Proteção Integral', 0.0, 4.0), ('Parque Estadual Marinho Banco Do Álvaro', 'Parque', 'Estadual', 'Proteção Integral', 0.0, 4.0), ('Reserva Biológica Do Lago Piratuba', 'Reserva Biológica', 'Federal', 'Proteção Integral', 388082.0, 2.0), ('Área De Proteção Ambiental De Algodoal-Maiandeua', 'Área de Proteção Ambiental', 'Estadual', 'Uso Sustentável', 2818.0, 6.0), ('Refúgio De Vida Silvestre Da Ilha Do Canela', 'Refúgio de Vida Silvestre', 'Municipal', 'Proteção Integral', 170.0, 6.0), ('Área De Relevante Interesse Ecológico Projeto Dinâmica Biológica De Fragmentos Florestais', 'Área de Relevante Interesse Ecológico', 'Federal', 'Uso Sustentável', 3336.0, 3.0), ('Parque Nacional De Anavilhanas', 'Parque', 'Federal', 'Proteção Integral', 350240.0, 3.0), ('Estação Ecológica De Jutaí-Solimões', 'Estação Ecológica', 'Federal', 'Proteção Integral', 289514.0, 3.0), ('Estação Ecológica De Maracá', 'Estação Ecológica', 'Federal', 'Proteção Integral', 154222.0, 8.0), ('Estação Ecológica Juami-Japurá', 'Estação Ecológica', 'Federal', 'Proteção Integral', 831355.0, 3.0), ('Floresta Nacional De Balata-Tufari', 'Floresta', 'Federal', 'Uso Sustentável', 1088825.0, 3.0), ('Floresta Nacional De Itaituba I', 'Floresta', 'Federal', 'Uso Sustentável', 213085.0, 6.0), ('Floresta Nacional De Itaituba Ii', 'Floresta', 'Federal', 'Uso Sustentável', 397751.0, 6.0), ('Floresta Nacional De Roraima', 'Floresta', 'Federal', 'Uso Sustentável', 169628.0, 8.0), ('Floresta Nacional De Saracá-Taquera', 'Floresta', 'Federal', 'Uso Sustentável', 441288.0, 6.0), ('Floresta Nacional Do Bom Futuro', 'Floresta', 'Federal', 'Uso Sustentável', 98359.0, 7.0), ('Floresta Nacional Do Jatuarana', 'Floresta', 'Federal', 'Uso Sustentável', 568289.0, 3.0), ('Floresta Nacional Do Tapajós', 'Floresta', 'Federal', 'Uso Sustentável', 525060.0, 6.0), ('Parque Nacional Viruá', 'Parque', 'Federal', 'Proteção Integral', 280984.0, 8.0), ('Reserva Biológica Do Gurupi', 'Reserva Biológica', 'Federal', 'Proteção Integral', 271465.0, 4.0), ('Reserva Biológica Do Jaru', 'Reserva Biológica', 'Federal', 'Proteção Integral', 346863.3406, 7.0), ('Reserva Biológica Do Rio Trombetas', 'Reserva Biológica', 'Federal', 'Proteção Integral', 407759.0, 6.0), ('Reserva Biológica Do Uatumã', 'Reserva Biológica', 'Federal', 'Proteção Integral', 938602.0, 3.0), ('Reserva Extrativista Chocoaré-Mato Grosso', 'Reserva Extrativista', 'Federal', 'Uso Sustentável', 4618.0, 6.0), ('Reserva Extrativista Lago Do Cuniã', 'Reserva Extrativista', 'Federal', 'Uso Sustentável', 76410.0, 7.0), ('Reserva Extrativista Do Médio Juruá', 'Reserva Extrativista', 'Federal', 'Uso Sustentável', 286957.0, 3.0), ('Parque Nacional Do Jamanxim', 'Parque', 'Federal', 'Proteção Integral', 862897.0, 6.0), ('Área De Proteção Ambiental Do Tapajós', 'Área de Proteção Ambiental', 'Federal', 'Uso Sustentável', 2040363.0, 6.0), ('Floresta Nacional Do Crepori', 'Floresta', 'Federal', 'Uso Susten ...
'jutai': 108, 'labrea': 109, 'manacapuru': 110, 'manaquiri': 111, 'manaus': 112, 'manicore': 113, 'maraa': 114, 'maues': 115, 'nhamunda': 116, 'nova olinda do norte': 117, 'novo airao': 118, 'novo aripuana': 119, 'parintins': 120, 'pauini': 121, 'presidente figueiredo': 122, 'rio preto da eva': 123, 'santa isabel do rio negro': 124, 'santo antonio do ica': 125, 'sao gabriel da cachoeira': 126, 'sao paulo de olivenca': 127, 'sao sebastiao do uatuma': 128, 'silves': 129, 'tabatinga': 130, 'tapaua': 131, 'tefe': 132, 'tonantins': 133, 'uarini': 134, 'urucara': 135, 'urucurituba': 136, 'alto alegre': 137, 'amajari': 138, 'boa vista': 139, 'bonfim': 140, 'canta': 141, 'caracarai': 142, 'caroebe': 143, 'iracema': 144, 'mucajai': 145, 'normandia': 146, 'pacaraima': 147, 'rorainopolis': 148, 'sao joao da baliza': 149, 'sao luiz': 150, 'uiramuta': 151, 'abaetetuba': 152, 'abel figueiredo': 153, 'acara': 154, 'afua': 155, 'agua azul do norte': 156, 'alenquer': 157, 'almeirim': 158, 'altamira': 159, 'anajas': 160, 'ananindeua': 161, 'anapu': 162, 'augusto correa': 163, 'aurora do para': 164, 'aveiro': 165, 'bagre': 166, 'baiao': 167, 'bannach': 168, 'barcarena': 169, 'belem': 170, 'belterra': 171, 'benevides': 172, 'bom jesus do tocantins': 336, 'bonito': 174, 'braganca': 175, 'brasil novo': 176, 'brejo grande do araguaia': 177, 'breu branco': 178, 'breves': 179, 'bujaru': 180, 'cachoeira do arari': 181, 'cachoeira do piria': 182, 'cameta': 183, 'canaa dos carajas': 184, 'capanema': 185, 'capitao poco': 186, 'castanhal': 187, 'chaves': 188, 'colares': 189, 'conceicao do araguaia': 190, 'concordia do para': 191, 'cumaru do norte': 192, 'curionopolis': 193, 'curralinho': 194, 'curua': 195, 'curuca': 196, 'dom eliseu': 197, 'eldorado do carajas': 198, 'faro': 199, 'floresta do araguaia': 200, 'garrafao do norte': 201, 'goianesia do para': 202, 'gurupa': ...

# %% [markdown]
# ### Insert Desmatamento Cidade

# %%
# %run insert_desmatamento_cidade.ipynb
# Out:
# Index(['ano', 'area_km2', 'cidade', 'geocode_ibge', 'state'], dtype='object')

# %% [markdown]
# ### Insert Desmatamento Area Indigena

# %%
# %run insert_desmatamento_indigena.ipynb
# Out:
# Index(['ano', 'area_km2', 'area_indigena'], dtype='object')

# %% [markdown]
# ### Insert Desmatamento Unidade Conservacao

# %%
# %run insert_desmatamento_unidade_conservacao.ipynb
# Out:
# Index(['ano', 'area_km2', 'unidade_conservacao'], dtype='object')

# %% [markdown]
# ### Insert Emissão

# %%
# %run insert_emissao.ipynb
# Out:
# 7

# %% [markdown]
# ### Insert Meteorologia

# %%
# %run insert_meteorologia.ipynb
