# %%
import psycopg2

conn = psycopg2.connect(
    dbname="ProjetoMC536",
    user="postgres",
    password="GSW30_curry",
    host="localhost",
    port="5432"
)

cursor = conn.cursor()

# %%
command = """
INSERT INTO "RegiaoAdministrativa" (nome) VALUES
('Amazônia Legal')
"""
cursor.execute(command)
conn.commit()
print("Região Administrativa inserida com sucesso.")
# Out:
# Região Administrativa inserida com sucesso.

# %%
command = """
INSERT INTO "RegiaoAdministrativa" (nome) VALUES
('Centro-Oeste'),
('Nordeste'),
('Norte'),
('Sudeste'),
('Sul')
"""

cursor.execute(command)
conn.commit()
print("Regiões Administrativas inseridas com sucesso.")
# Out:
# Regiões Administrativas inseridas com sucesso.

# %%
cursor.close()
conn.close()
# Close the connection

# %%
conn.rollback()
# Rollback the transaction
